# %% [markdown]
# # Libraries Covered

# %%
import pandas as pd
import numpy as np
import scipy
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %pylab inline

import seaborn as sns
sns.set()


#  Scipy Stats library
from scipy import stats
stats.linregress # Lin reg


# Linear and Logistic using Statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf # using patsy (takes and depends on name of df)
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Linear Regression using sklearn

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Logistic Regression using Sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics


# More Machine Learning Models
from sklearn import model_selection, metrics, linear_model, datasets, feature_selection, tree
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from seaborn import pairplot, heatmap

# Cross validation

from sklearn import model_selection, metrics, linear_model, datasets, feature_selection, tree
model_selection.KFold(n_splits=4,shuffle=True)


# Clustering

from sklearn.cluster import KMeans
from sklearn import preprocessing

# Deep Learning

from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import tensorflow_datasets as tfds
from sklearn import preprocessing
# scaled_inputs = preprocessing.scale(unscaled_inputs_equal_priors)


# Visualiation

import matplotlib
import seaborn as sns
sns.set_style('whitegrid')
import time
import matplotlib
from matplotlib import colors
import matplotlib.pyplot as plt
# %pylab inline

# Visualization 3D

import numpy as np
import oafrom mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Visualization Bokeh

from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from bokeh.models import DatetimeTickFormatter



# Hypothesis Testing - Statistics

from scipy import stats, special
stats.ttest_1samp()
stats.ttest_ind()
stats.chi2_contingency(#crosstab-contingency table)
stats.shapiro()
stats.chisquare()
    
    
# Measures - Statistics
    
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_s
metrics.r2_s() # for lin reg
metrics.mean_absolute_error()
metrics.mean_squared_error()
metrics.accuracy_score() # for classification
metrics.confusion_matrix()
    

# Decision Trees
    
from sklearn import tree
